# %% [markdown]
# # Step 6: Model Training
# ## IBM Telco Customer Churn Dataset
#
# **Objective:** Train and compare three classifiers on preprocessed training data.
#
# | Model | Role |
# |-------|------|
# | **LightGBM** | Primary model — best for tabular churn prediction |
# | **Logistic Regression** | Interpretable linear baseline |
# | **Random Forest** | Tree ensemble comparison |

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from train_models import run_training, load_model

result = run_training()
result

# %%
# Training sanity check
for name, info in result["registry"]["models"].items():
    print(f"{name}: train accuracy = {info['train_accuracy']:.4f}")

lgbm = load_model("lightgbm")
print(f"\nLightGBM loaded: {type(lgbm).__name__}")
