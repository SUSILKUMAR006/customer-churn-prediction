# %% [markdown]
# # Step 5: Data Preprocessing
# ## IBM Telco Customer Churn Dataset
#
# **Objective:** Prepare data for machine learning with proper encoding, scaling, and train-test split.
#
# ### Steps
# 1. Select numeric + categorical features
# 2. Stratified 80/20 train-test split
# 3. `StandardScaler` on numeric features (fit on train)
# 4. `OneHotEncoder` on categorical features (fit on train)
# 5. Save preprocessor and arrays for model training

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from data_loader import load_engineered_data
from preprocessing import run_preprocessing, load_train_test_data, load_preprocessor

df = load_engineered_data()
result = run_preprocessing(df)
result

# %%
data = load_train_test_data()
print(f"X_train shape: {data['X_train'].shape}")
print(f"X_test shape:  {data['X_test'].shape}")
print(f"Train churn rate: {data['y_train'].mean()*100:.2f}%")
print(f"Test churn rate:  {data['y_test'].mean()*100:.2f}%")

# %%
import json
from config import FEATURE_NAMES_FILE

with open(FEATURE_NAMES_FILE) as f:
    feature_names = json.load(f)

print(f"Total processed features: {len(feature_names)}")
feature_names[:20]
