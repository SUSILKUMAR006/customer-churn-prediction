# %% [markdown]
# # Step 4: Feature Engineering
# ## IBM Telco Customer Churn Dataset
#
# **Objective:** Create domain-driven features from EDA insights to improve model performance.
#
# ### Feature categories
# - **Billing & tenure** — AvgMonthlySpend, TenureGroup, ChargeIncreaseRatio
# - **Service engagement** — ServiceCount, HasStreaming, HasSupportBundle
# - **Risk flags** — IsMonthToMonth, IsElectronicCheck, IsAutoPay, IsFiber
# - **Demographics** — HasFamily, IsNewCustomer

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from data_loader import load_cleaned_data
from feature_engineering import engineer_features, get_feature_churn_comparison, save_engineered_data
from config import ENGINEERED_DATA_FILE

df = load_cleaned_data()
df_eng, report = engineer_features(df)
print(f"Shape: {df.shape} → {df_eng.shape}")
print(f"New features: {len(report['new_features'])}")

# %%
# Feature definitions
pd.DataFrame(
    {"Feature": list(report["feature_definitions"].keys()),
     "Definition": list(report["feature_definitions"].values())}
)

# %%
# Churned vs retained comparison
get_feature_churn_comparison(df_eng)

# %%
save_engineered_data(df_eng)
print(f"Saved: {ENGINEERED_DATA_FILE}")
df_eng.head()
